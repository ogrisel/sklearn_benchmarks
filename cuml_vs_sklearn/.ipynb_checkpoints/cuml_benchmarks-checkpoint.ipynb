# %%
import pandas as pd

# %matplotlib inline

# %%
from utils import plot

# %% [markdown]
# ### NEIGHBORS

# %%
neighbors_bench = pd.read_csv("benchmark_results_nearest_neighbors.csv")
neighbors_bench
# Out:
#    Unnamed: 0   cu_time    cpu_time     speedup  n_samples  n_features  \
# 0           0  0.125206   10.770020   86.018404      16384          32
# 1           1  0.137626   11.943944   86.785559      16384         256
# 2           2  0.190947  144.746197  758.044563      65536          32
# 3           3  0.248789  172.784662  694.503950      65536         256
# 4           4  0.205056   12.575287   61.326125      16384          32
# 5           5  0.215172   13.321146   61.909347      16384         256
# 6           6  0.669506  152.798990  228.226605      65536          32
# 7           7  0.704928  179.143823  254.130695      65536         256
#
#    n_neighbors  n_jobs              algo dataset_name input_type
# 0            5      -1  NearestNeighbors        blobs      numpy
# 1            5      -1  NearestNeighbors        blobs      numpy
# 2            5      -1  NearestNeighbors        blobs      numpy
# 3            5      -1  NearestNeighbors        blobs      numpy
# 4         1024      -1  NearestNeighbors        blobs      numpy
# 5         1024      -1  NearestNeighbors        blobs      numpy
# 6         1024      -1  NearestNeighbors        blobs      numpy
# 7         1024      -1  NearestNeighbors        blobs      numpy

# %%
plot(neighbors_bench, split="n_neighbors")

# %% [markdown]
# ### DBSCAN

# %%
dbscan_bench = pd.read_csv("benchmark_results_dbscan.csv")
dbscan_bench
# Out:
#    Unnamed: 0   cu_time   cpu_time     speedup  n_samples  n_features    algo  \
# 0           0  0.016944   2.482351  146.501780      16384          32  DBSCAN
# 1           1  0.036790   2.965583   80.608098      16384         256  DBSCAN
# 2           2  0.164477  39.211306  238.399430      65536          32  DBSCAN
# 3           3  0.425731  46.459193  109.128124      65536         256  DBSCAN
#
#   dataset_name input_type
# 0        blobs      numpy
# 1        blobs      numpy
# 2        blobs      numpy
# 3        blobs      numpy

# %%
plot(dbscan_bench)

# %% [markdown]
# ### KMEANS

# %%
kmeans_bench = pd.read_csv("benchmark_results_kmeans.csv")
kmeans_bench
# Out:
#    Unnamed: 0   cu_time   cpu_time    speedup  n_samples  n_features  \
# 0           0  0.029467   0.158092   5.364982      16384          32
# 1           1  0.031399   0.305483   9.728978      16384         256
# 2           2  0.139531   0.276553   1.982017      65536          32
# 3           3  0.092962   0.976105  10.500069      65536         256
# 4           4  0.159849   1.807537  11.307764      16384          32
# 5           5  0.067800   2.443948  36.046277      16384         256
# 6           6  0.421320   8.287898  19.671268      65536          32
# 7           7  0.235185  10.100687  42.947768      65536         256
#
#    n_clusters    algo dataset_name input_type
# 0           8  KMeans        blobs      numpy
# 1           8  KMeans        blobs      numpy
# 2           8  KMeans        blobs      numpy
# 3           8  KMeans        blobs      numpy
# 4         100  KMeans        blobs      numpy
# 5         100  KMeans        blobs      numpy
# 6         100  KMeans        blobs      numpy
# 7         100  KMeans        blobs      numpy

# %%
plot(kmeans_bench, split="n_clusters")

# %% [markdown]
# ### T-SNE

# %%
tsne_bench = pd.read_csv("benchmark_results_tsne.csv")
tsne_bench
# Out:
#    Unnamed: 0   cu_time    cpu_time     speedup  n_samples  n_features  \
# 0           0  1.282573   69.222053   53.971239      16384          32
# 1           1  1.326208   76.184011   57.445000      16384         256
# 2           2  2.028869  301.388887  148.550219      65536          32
# 3           3  2.094445  339.951307  162.310927      65536         256
#
#    n_jobs  algo dataset_name input_type
# 0      -1  TSNE        blobs      numpy
# 1      -1  TSNE        blobs      numpy
# 2      -1  TSNE        blobs      numpy
# 3      -1  TSNE        blobs      numpy

# %%
plot(tsne_bench)

# %% [markdown]
# ### LINEAR MODELS

# %%
linear_bench = pd.read_csv("benchmark_results_linear_models.csv")
linear_bench
# Out:
#     Unnamed: 0   cu_time  cpu_time    speedup  n_samples  n_features  \
# 0            0  0.005070  0.008290   1.635175      16384          32
# 1            1  0.019561  0.096073   4.911499      16384         256
# 2            2  0.005603  0.025792   4.603558      65536          32
# 3            3  0.029607  0.348192  11.760430      65536         256
# 4            4  0.010180  0.041724   4.098478      16384          32
# 5            5  0.018243  0.075271   4.125931      16384         256
# 6            6  0.013175  0.192839  14.636471      65536          32
# 7            7  0.038297  0.318751   8.323051      65536         256
# 8            8  0.005255  0.003827   0.728188      16384          32
# 9            9  0.018165  0.021610   1.189686      16384         256
# 10          10  0.006211  0.011427   1.839853      65536          32
# 11          11  0.029590  0.085760   2.898314      65536         256
# 12          12  0.006618  0.004060   0.613423      16384          32
# 13          13  0.039955  0.025953   0.649557      16384         256
# 14          14  0.007761  0.010303   1.327476      65536          32
# 15          15  0.046150  0.109685   2.376689      65536         256
# 16          16  0.006478  0.005200   0.802665      16384          32
# 17          17  0.040159  0.025825   0.643058      16384         256
# 18          18  0.007559  0.011135   1.473080      65536          32
# 19          19  0.046269  0.116227   2.511970      65536         256
#
#                   algo    dataset_name input_type
# 0     LinearRegression      regression      numpy
# 1     LinearRegression      regression      numpy
# 2     LinearRegression      regression      numpy
# 3     LinearRegression      regression      numpy
# 4   LogisticRegression  classification      numpy
# 5   LogisticRegression  classification      numpy
# 6   LogisticRegression  classification      numpy
# 7   LogisticRegression  classification      numpy
# 8                Ridge      regression      numpy
# 9                Ridge      regression      numpy
# 10               Ridge      regression      numpy
# 11               Ridge      regression      numpy
# 12               Lasso      regression      numpy
# 13               Lasso      regression      numpy
# 14               Lasso      regression      numpy
# 15               Lasso      regression      numpy
# 16          ElasticNet      regression      numpy
# 17          ElasticNet      regression      numpy
# 18          ElasticNet      regression      numpy
# 19          ElasticNet      regression      numpy

# %%
plot(linear_bench)

# %% [markdown]
# ### PCA

# %%
pca_bench = pd.read_csv("benchmark_results_pca.csv")
pca_bench
# Out:
#    Unnamed: 0   cu_time   cpu_time    speedup  n_samples  n_features  \
# 0           0  0.071683   0.198890   2.774567      16384        1000
# 1           1  2.678514   1.683586   0.628552      16384       10000
# 2           2  0.118927   0.873719   7.346672      65536        1000
# 3           3  4.011471   7.359008   1.834491      65536       10000
# 4           4  0.068855   0.315968   4.588871      16384        1000
# 5           5  2.669515   3.195875   1.197174      16384       10000
# 6           6  0.119305   1.386034  11.617536      65536        1000
# 7           7  4.004422  12.781872   3.191939      65536       10000
#
#    n_components algo dataset_name input_type
# 0            10  PCA        blobs      numpy
# 1            10  PCA        blobs      numpy
# 2            10  PCA        blobs      numpy
# 3            10  PCA        blobs      numpy
# 4           100  PCA        blobs      numpy
# 5           100  PCA        blobs      numpy
# 6           100  PCA        blobs      numpy
# 7           100  PCA        blobs      numpy

# %%
plot(pca_bench, split="n_components")

# %% [markdown]
# ### TRUNCATED SVD

# %%
tsvd_bench = pd.read_csv("benchmark_results_truncated_svd.csv")
tsvd_bench
# Out:
#    Unnamed: 0   cu_time   cpu_time    speedup  n_samples  n_features  \
# 0           0  0.078461   0.147405   1.878693      16384        1000
# 1           1  2.675413   1.218041   0.455272      16384       10000
# 2           2  0.129272   0.641884   4.965395      65536        1000
# 3           3  4.012623   5.375936   1.339756      65536       10000
# 4           4  0.081600   0.400588   4.909164      16384        1000
# 5           5  2.686955   2.805702   1.044194      16384       10000
# 6           6  0.135598   1.613627  11.900088      65536        1000
# 7           7  4.033782  10.765576   2.668854      65536       10000
#
#    n_components  algo dataset_name input_type
# 0            10  TSVD        blobs      numpy
# 1            10  TSVD        blobs      numpy
# 2            10  TSVD        blobs      numpy
# 3            10  TSVD        blobs      numpy
# 4           100  TSVD        blobs      numpy
# 5           100  TSVD        blobs      numpy
# 6           100  TSVD        blobs      numpy
# 7           100  TSVD        blobs      numpy

# %%
plot(tsvd_bench, split="n_components")

# %% [markdown]
# ### RANDOM FOREST

# %%
rf_bench = pd.read_csv("benchmark_results_random_forest.csv")
rf_bench
# Out:
#     Unnamed: 0    cu_time    cpu_time     speedup  n_samples  n_features  \
# 0            0   0.176110    0.646555    3.671325      16384          32
# 1            1   0.383812    2.054053    5.351711      16384         256
# 2            2   0.186893    2.953927   15.805464      65536          32
# 3            3   0.376731   13.389446   35.541095      65536         256
# 4            4   0.267488    3.052663   11.412336      16384          32
# 5            5   1.595183   28.190371   17.672182      16384         256
# 6            6   0.579788   19.486005   33.608861      65536          32
# 7            7   2.561026  418.997287  163.605239      65536         256
# 8            8   0.277989    0.643984    2.316579      16384          32
# 9            9   0.396064    2.053360    5.184418      16384         256
# 10          10   0.303517    3.051935   10.055239      65536          32
# 11          11   0.661069   11.599108   17.545995      65536         256
# 12          12   0.549001    2.249287    4.097056      16384          32
# 13          13   4.321921   17.473610    4.043019      16384         256
# 14          14   1.065003   11.363375   10.669807      65536          32
# 15          15  11.557981   89.832354    7.772322      65536         256
#
#    max_features  n_estimators  n_jobs                    algo    dataset_name  \
# 0          sqrt           100      -1  RandomForestClassifier  classification
# 1          sqrt           100      -1  RandomForestClassifier  classification
# 2          sqrt           100      -1  RandomForestClassifier  classification
# 3          sqrt           100      -1  RandomForestClassifier  classification
# 4           1.0           100      -1  RandomForestClassifier  classification
# 5           1.0           100      -1  RandomForestClassifier  classification
# 6           1.0           100      -1  RandomForestClassifier  classification
# 7           1.0           100      -1  RandomForestClassifier  classification
# 8          sqrt           100      -1   RandomForestRegressor      regression
# 9          sqrt           100      -1   RandomForestRegressor      regression
# 10         sqrt           100      -1   RandomForestRegressor      regression
# 11         sqrt           100      -1   RandomForestRegressor      regression
# 12          1.0           100      -1   RandomForestRegressor      regression
# 13          1.0           100      -1   RandomForestRegressor      regression
# 14          1.0           100      -1   RandomForestRegressor      regression
# 15          1.0           100      -1   RandomForestRegressor      regression
#
#    input_type
# 0       numpy
# 1       numpy
# 2       numpy
# 3       numpy
# 4       numpy
# 5       numpy
# 6       numpy
# 7       numpy
# 8       numpy
# 9       numpy
# 10      numpy
# 11      numpy
# 12      numpy
# 13      numpy
# 14      numpy
# 15      numpy

# %%
plot(rf_bench, split="max_features")

# %% [markdown]
# ### RANDOM PROJECTION

# %%
random_proj_bench = pd.read_csv("benchmark_results_random_projection.csv")
random_proj_bench
# Out:
#     Unnamed: 0   cu_time   cpu_time    speedup  n_samples  n_features  \
# 0            0  0.029423   0.202796   6.892439      16384        1000
# 1            1  0.267571   2.313780   8.647344      16384       10000
# 2            2  0.107920   1.036424   9.603638      65536        1000
# 3            3  1.053426  10.298787   9.776474      65536       10000
# 4            4  0.029957   0.223192   7.450398      16384        1000
# 5            5  0.262087   2.531984   9.660840      16384       10000
# 6            6  0.112160   1.124847  10.028907      65536        1000
# 7            7  1.038592  10.941446  10.534880      65536       10000
# 8            8  0.031550   0.069685   2.208680      16384        1000
# 9            9  0.264918   0.570626   2.153975      16384       10000
# 10          10  0.106002   0.245786   2.318694      65536        1000
# 11          11  1.028886   2.272551   2.208749      65536       10000
# 12          12  0.037119   0.099927   2.692087      16384        1000
# 13          13  0.268728   0.717108   2.668522      16384       10000
# 14          14  0.114408   0.487771   4.263443      65536        1000
# 15          15  1.042985   3.022349   2.897786      65536       10000
#
#     n_components                      algo dataset_name input_type
# 0             10  GaussianRandomProjection        blobs      numpy
# 1             10  GaussianRandomProjection        blobs      numpy
# 2             10  GaussianRandomProjection        blobs      numpy
# 3             10  GaussianRandomProjection        blobs      numpy
# 4            100  GaussianRandomProjection        blobs      numpy
# 5            100  GaussianRandomProjection        blobs      numpy
# 6            100  GaussianRandomProjection        blobs      numpy
# 7            100  GaussianRandomProjection        blobs      numpy
# 8             10    SparseRandomProjection        blobs      numpy
# 9             10    SparseRandomProjection        blobs      numpy
# 10            10    SparseRandomProjection        blobs      numpy
# 11            10    SparseRandomProjection        blobs      numpy
# 12           100    SparseRandomProjection        blobs      numpy
# 13           100    SparseRandomProjection        blobs      numpy
# 14           100    SparseRandomProjection        blobs      numpy
# 15           100    SparseRandomProjection        blobs      numpy

# %%
plot(random_proj_bench, split="n_components")

# %% [markdown]
# ### SVM

# %%
svm_bench = pd.read_csv("benchmark_results_svm.csv")
svm_bench
# Out:
#     Unnamed: 0    cu_time     cpu_time      speedup  n_samples  n_features  \
# 0            0   0.045067     0.902157    20.018315      16384          32
# 1            1   0.323842    19.689932    60.800991      16384         256
# 2            2   0.283732    98.196077   346.086917      65536          32
# 3            3  24.165422   857.610961    35.489178      65536         256
# 4            4   0.131425     5.148031    39.170896      16384          32
# 5            5   0.395905   100.866332   254.773760      16384         256
# 6            6   0.612549   130.150489   212.473490      65536          32
# 7            7   1.516795  1650.348700  1088.049820      65536         256
# 8            8   0.562010     0.640277     1.139263      16384          32
# 9            9   5.040489    16.543550     3.282132      16384         256
# 10          10   0.654477     2.004620     3.062932      65536          32
# 11          11   8.298777    88.716766    10.690342      65536         256
# 12          12   0.094389    19.601797   207.669387      16384          32
# 13          13   0.186236    43.625793   234.250472      16384         256
# 14          14   0.727746   499.557287   686.444106      65536          32
# 15          15   1.348627  1233.402912   914.562031      65536         256
#
#           algo    dataset_name input_type
# 0   SVC-Linear  classification      numpy
# 1   SVC-Linear  classification      numpy
# 2   SVC-Linear  classification      numpy
# 3   SVC-Linear  classification      numpy
# 4      SVC-RBF  classification      numpy
# 5      SVC-RBF  classification      numpy
# 6      SVC-RBF  classification      numpy
# 7      SVC-RBF  classification      numpy
# 8   SVR-Linear      regression      numpy
# 9   SVR-Linear      regression      numpy
# 10  SVR-Linear      regression      numpy
# 11  SVR-Linear      regression      numpy
# 12     SVR-RBF      regression      numpy
# 13     SVR-RBF      regression      numpy
# 14     SVR-RBF      regression      numpy
# 15     SVR-RBF      regression      numpy

# %%
plot(svm_bench)
