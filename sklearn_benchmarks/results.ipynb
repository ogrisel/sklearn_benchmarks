# %% [markdown]
# # Imports

# %%
from utils import print_time_report, print_results, plot_results

# %% [markdown]
# <br></br>
# # Time report

# %%
print_time_report()
# Out:
#                 hour  min  sec
# algo
# KMeans             0    0   46
# daal4py_KMeans     0    0   27
# total              0    1   14

# %% [markdown]
# <br></br>
# # KNeighborsClassifier - Brute Force

# %%
print_results(algo="KNeighborsClassifier", versus_lib="daal4py")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-efeb9abe0608> in <module>
# ----> 1 print_results(algo="KNeighborsClassifier", versus_lib="daal4py")
#
# ~/code/inria/sklearn_benchmarks/sklearn_benchmarks/utils.py in print_results(algo, versus_lib, compare_cols)
#      80
#      81 def print_results(algo="", versus_lib="", compare_cols=[]):
# ---> 82     data = _make_dataset(algo, versus_lib, compare_cols=compare_cols)
#      83     qgrid_widget = qgrid.show_grid(data, show_toolbar=True)
#      84     display(qgrid_widget)
#
# ~/code/inria/sklearn_benchmarks/sklearn_benchmarks/utils.py in _make_dataset(algo, lib, speedup_col, stdev_speedup_col, compare_cols)
#      98 ):
#      99     results_path = Path(__file__).resolve().parent / "results"
# --> 100     lib_df = pd.read_csv("%s/%s_%s.csv" % (str(results_path), lib, algo))
#     101     skl_df = pd.read_csv("%s/sklearn_%s.csv" % (str(results_path), algo))
#     102     lib_suffix = "_" + lib
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# --> 610     return _read(filepath_or_buffer, kwds)
#     611
#     612
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     460
#     461     # Create the parser.
# --> 462     parser = TextFileReader(filepath_or_buffer, **kwds)
#     463
#     464     if chunksize or iterator:
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     817             self.options["has_index_names"] = kwds["has_index_names"]
#     818
# --> 819         self._engine = self._make_engine(self.engine)
#     820
#     821     def close(self):
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1048             )
#    1049         # error: Too many arguments for "ParserBase"
# -> 1050         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1051
#    1052     def _failover_to_python(self):
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1865
#    1866         # open handles
# -> 1867         self._open_handles(src, kwds)
#    1868         assert self.handles is not None
#    1869         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1360         Let the readers open IOHanldes after they are done with their potential raises.
#    1361         """
# -> 1362         self.handles = get_handle(
#    1363             src,
#    1364             "r",
#
# ~/opt/miniconda3/envs/sklbench/lib/python3.8/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/mathisbatoul/code/inria/sklearn_benchmarks/sklearn_benchmarks/results/daal4py_KNeighborsClassifier.csv'

# %%
plot_results(algo="KNeighborsClassifier", versus_lib="daal4py", group_by_cols=["algorithm", "n_neighbors", "function"], split_hist_by=["n_jobs"])

# %% [markdown]
# <br></br>
# # KNeighborsClassifier - KD Tree

# %%
print_results(algo="KNeighborsClassifier_kd_tree", versus_lib="daal4py")

# %%
plot_results(algo="KNeighborsClassifier_kd_tree", versus_lib="daal4py", group_by_cols=["algorithm", "n_neighbors", "function"], split_hist_by=["n_jobs"])

# %% [markdown]
# <br></br>
# # KMeans

# %%
from utils import _make_dataset
data = _make_dataset('KMeans', 'daal4py', compare_cols=["n_iter"])

# %%
data[["estimator", "lib", "function", "n_samples", "n_features", "n_iter_sklearn", "n_iter_daal4py"]].sort_values(["n_iter_sklearn", "n_iter_daal4py"])
# Out:
#    estimator      lib function  n_samples  n_features  n_iter_sklearn  \
# 9     KMeans  sklearn      fit      10000           2            28.0
# 0     KMeans  sklearn      fit      10000           2            30.0
# 18    KMeans  sklearn      fit      10000         100            30.0
# 27    KMeans  sklearn      fit    1000000           2            30.0
# 36    KMeans  sklearn      fit    1000000         100            30.0
# 45    KMeans  sklearn      fit    1000000         100            30.0
# 1     KMeans  sklearn  predict       1000           2             NaN
# 2     KMeans  sklearn  predict          1           2             NaN
# 3     KMeans  sklearn      fit      10000           2             NaN
# 4     KMeans  sklearn  predict       1000           2             NaN
# 5     KMeans  sklearn  predict          1           2             NaN
# 6     KMeans  sklearn      fit      10000           2             NaN
# 7     KMeans  sklearn  predict       1000           2             NaN
# 8     KMeans  sklearn  predict          1           2             NaN
# 10    KMeans  sklearn  predict       1000           2             NaN
# 11    KMeans  sklearn  predict          1           2             NaN
# 12    KMeans  sklearn      fit      10000         100             NaN
# 13    KMeans  sklearn  predict       1000         100             NaN
# 14    KMeans  sklearn  predict          1         100             NaN
# 15    KMeans  sklearn      fit      10000         100             NaN
# 16    KMeans  sklearn  predict       1000         100             NaN
# 17    KMeans  sklearn  predict          1         100             NaN
# 19    KMeans  sklearn  predict       1000         100             NaN
# 20    KMeans  sklearn  predict          1         100             NaN
# 21    KMeans  sklearn      fit      10000         100             NaN
# 22    KMeans  sklearn  predict       1000         100             NaN
# 23    KMeans  sklearn  predict          1         100             NaN
# 24    KMeans  sklearn      fit    1000000           2             NaN
# 25    KMeans  sklearn  predict       1000           2             NaN
# 26    KMeans  sklearn  predict          1           2             NaN
# 28    KMeans  sklearn  predict       1000           2             NaN
# 29    KMeans  sklearn  predict          1           2             NaN
# 30    KMeans  sklearn      fit    1000000           2             NaN
# 31    KMeans  sklearn  predict       1000           2             NaN
# 32    KMeans  sklearn  predict          1           2             NaN
# 33    KMeans  sklearn      fit    1000000           2             NaN
# 34    KMeans  sklearn  predict       1000           2             NaN
# 35    KMeans  sklearn  predict          1           2             NaN
# 37    KMeans  sklearn  predict       1000         100             NaN
# 38    KMeans  sklearn  predict          1         100             NaN
# 39    KMeans  sklearn      fit    1000000         100             NaN
# 40    KMeans  sklearn  predict       1000         100             NaN
# 41    KMeans  sklearn  predict          1         100             NaN
# 42    KMeans  sklearn      fit    1000000         100             NaN
# 43    KMeans  sklearn  predict       1000         100             NaN
# 44    KMeans  sklearn  predict          1         100             NaN
# 46    KMeans  sklearn  predict       1000         100             NaN
# 47    KMeans  sklearn  predict          1         100             NaN
#
#     n_iter_daal4py
# 9             30.0
# 0             30.0
# 18            30.0
# 27            30.0
# 36            30.0
# 45            30.0
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# 6              NaN
# 7              NaN
# 8              NaN
# 10             NaN
# 11             NaN
# 12             NaN
# 13             NaN
# 14             NaN
# 15             NaN
# 16             NaN
# 17             NaN
# 19             NaN
# 20             NaN
# 21             NaN
# 22             NaN
# 23             NaN
# 24             NaN
# 25             NaN
# 26             NaN
# 28             NaN
# 29             NaN
# 30             NaN
# 31             NaN
# 32             NaN
# 33             NaN
# 34             NaN
# 35             NaN
# 37             NaN
# 38             NaN
# 39             NaN
# 40             NaN
# 41             NaN
# 42             NaN
# 43             NaN
# 44             NaN
# 46             NaN
# 47             NaN

# %%
print_results(algo="KMeans", versus_lib="daal4py", compare_cols=["n_iter"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-a1824be21472> in <module>
# ----> 1 print_results(algo="KMeans", versus_lib="daal4py", compare_cols=["n_iter"])
#
# NameError: name 'print_results' is not defined

# %%
plot_results(algo="KMeans", versus_lib="daal4py", group_by_cols=["init", "max_iter", "n_clusters", "n_init", "tol", "function"], compare_cols=["n_iter"])
