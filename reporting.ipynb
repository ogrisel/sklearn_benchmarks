# %% [markdown]
# # Benchmarking reports

# %%
from sklearn_benchmarks.report import Reporting

# %%
Reporting(config_file_path="config.yml").run()
# Out:
# ## Time report
#                               hour  min       sec
# algo
# KNeighborsClassifier           0.0  0.0  0.370526
# daal4py_KNeighborsClassifier   0.0  0.0  1.834833
# KMeans                         0.0  0.0  0.572963
# daal4py_KMeans                 0.0  0.0  0.199832
# LogisticRegression             0.0  0.0  0.731527
# daal4py_LogisticRegression     0.0  0.0  0.755823
# Ridge                          0.0  0.0  0.620400
# daal4py_Ridge                  0.0  0.0  0.608038
# total                          0.0  0.0  5.748906
# ## KNeighborsClassifier
#       estimator_sklearn lib_sklearn function_sklearn  mean_sklearn  \
# 0  KNeighborsClassifier     sklearn              fit        0.0003
# 1  KNeighborsClassifier     sklearn          predict        0.0010
# 2  KNeighborsClassifier     sklearn          predict        0.0006
#
#    stdev_sklearn  n_samples_sklearn  n_features_sklearn  \
# 0         0.0001               1000                   2
# ...
